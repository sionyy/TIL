# %%
#주어진 문자열에서 숫자, 문자, 기호가 각각 몇개인지를 판단하는 함수를 작성해보세요.
def check(target_str):
    pass
    target_str = 'aabbcc1122'
    lst_str = list(target_str)
    
    count_str = 0
    for i in range(len(lst_str)):
        if type(lst_str[i]) == str:
            count_str = count_str +1
    
    return count_str


# 문자 : 10개, 숫자 : 3개, 기호 : 7개

# %%
numbers = [3,2,5,1]
result = sorted(numbers)
print(numbers,result)
# Out:
# [3, 2, 5, 1] [1, 2, 3, 5]

# %% [markdown]
# 데이터구조 = 자료구조
